# %% [markdown]
# # SCRAPING DATA

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.6 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
from google_play_scraper import app, reviews, Sort
import pandas as pd
import numpy as np
import datetime

# %%
app_id = 'com.openai.chatgpt'

def get_reviews(app_id, lang='id', count=2000, sort=Sort.NEWEST, filter_score_with=None, filter_device_with=None, continuation_token=None):
    try:
        result, continuation_token = reviews(
            app_id,
            lang=lang,
            country='id',
            sort=sort,
            count=count,
            filter_score_with=filter_score_with,
            filter_device_with=filter_device_with,
            continuation_token=continuation_token
        )

        return result, continuation_token
    except Exception as e:
        print("Error:", e)
        return None, None

reviews, continuation_token = get_reviews(app_id)

if reviews is not None:
    print("Jumlah ulasan:", len(reviews))
    if len(reviews) > 0:
        print("Contoh ulasan:")
        print(reviews[0])
else:
    print("Tidak dapat mengambil ulasan.")
# Out:
# Jumlah ulasan: 2000
# Contoh ulasan:
# {'reviewId': 'd91c558a-c4b6-409c-be63-ee58f23233d3', 'userName': 'Amanah Lawfirm', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU5I-gQTB-jgyVpswLOLNnImQ3PfmPEP2N80oofWIN_YvLe6W2x', 'content': 'on banget', 'score': 5, 'thumbsUpCount': 0, 'reviewCreatedVersion': '1.2025.283', 'at': datetime.datetime(2025, 10, 18, 7, 12, 44), 'replyContent': None, 'repliedAt': None, 'appVersion': '1.2025.283'}

# %%
import csv

def export_to_csv(reviews, file_name='hasil_scrap_ulasan_ChatGPT.csv'):
    if reviews:
        fieldnames = ['Review ID', 'Username', 'Rating', 'Review Text', 'Date']

        with open(file_name, mode='w', newline='', encoding='utf-8') as csv_file:
            writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
            writer.writeheader()

            for review in reviews:
                writer.writerow({
                    'Review ID': review['reviewId'],
                    'Username': review['userName'],
                    'Rating': review['score'],
                    'Review Text': review['content'],
                    'Date': review['at']
                })

        print(f"Data berhasil diekspor ke '{file_name}'")
    else:
        print("Tidak ada data ulasan untuk diekspor.")

export_to_csv(reviews)
# Out:
# Data berhasil diekspor ke 'hasil_scrap_ulasan_ChatGPT.csv'

# %%
data = pd.read_csv('hasil_scrap_ulasan_ChatGPT.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Review ID    2000 non-null   object
#  1   Username     2000 non-null   object
#  2   Rating       2000 non-null   int64
#  3   Review Text  2000 non-null   object
#  4   Date         2000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 78.3+ KB

# %%
data.head(5)
# Out:
#                               Review ID           Username  Rating  \
# 0  d91c558a-c4b6-409c-be63-ee58f23233d3     Amanah Lawfirm       5
# 1  f3c18b9e-6823-4e26-8b9b-66f0e91356f9         Abdul Azid       5
# 2  32c7f57f-b71c-416a-b6fc-0884913cca8c       Safwan Hasbi       5
# 3  e92797f2-38e3-49f0-b147-75f6fd017802          Aku Benar       4
# 4  65ae94de-59a3-4eb9-bdd6-0d3830d2e6b1  Anggerjiwa Pusaka       5
#
#                                          Review Text                 Date
# 0                                          on banget  2025-10-18 07:12:44
# 1                                         luar biasa  2025-10-18 07:11:35
# 2                                                 👍🏻  2025-10-18 07:09:36
# 3  aplikasi nya bagus bisa serba guna tapi buat u...  2025-10-18 07:07:46
# 4                                               good  2025-10-18 07:05:36
